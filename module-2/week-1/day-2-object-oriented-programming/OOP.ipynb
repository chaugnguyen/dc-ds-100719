# %% [markdown]
# # Object Oriented Programing - Part 1
# ## Or why a data scientist should care about classes

# %% [markdown]
# ## Scenario
#
# You want to build an automated datascience pipeline to monitor and predict stock performance.
# What would you do?
#
# ![stocks](img/stocks.jpeg)

# %% [markdown]
# While we won't complete this today, in order to build that you'd need to:
#
# - describe the limits of custom functions
# - discover where classes are used in python packages
# - identify and paraphrase the vocabulary of Object Oriented Programming
# - build a new small sample class
# - map out the blueprint of a class for the stock monitoring data science pipeline

# %% [markdown]
# ### Let's start with the familiar: functions, why do we care about them?

# %% [markdown]
# But, how is a function like a pipe?

# %% [markdown]
# ![pipes](img/funtions-pipe.jpeg)

# %% [markdown]
# **What if** there was a way to bundle your input data, output data, and a bunch of functions _all together_ in a repeatable fashion?

# %% [markdown]
# Well, _**there is**_.

# %% [markdown]
# Or to put it differently:

# %% [markdown]
# #### HI BILLY MAYS HERE

# %% [markdown]
# ![mayes](img/mayes.png)

# %% [markdown]
# #### Example 1
# When we use `type()` what are we checking?
#
# ```
# example = ["one", "two", 3]
# type(example)
# type(example[-1])
# ```

# %% [markdown]
# `example` is an _object_ of _class type_ **list**

# %% [markdown]
# What can we know about `example` now that we know it is a **list** ?

# %% [markdown]
# #### Example 2
#
# ```
# import pandas as pd
#
# sampledf = pd.Dataframe()
#
# ```

# %%
import pandas as pd

sampledf = pd.DataFrame()

# %% [markdown]
# When we create an "object", using the blue-print of a _class_, even when it is **empty** that is called _initializing_ the object.

# %% [markdown]
# Even though it is empty, it is still an _object_ of _class_ pandas DataFrame.

# %%
type(sampledf)

# %% [markdown]
# What do we know we can ask about this object?
# What are its _attributes_ ?

# %%
sampledf.columns

# %% [markdown]
# What about _methods_ ? What methods are available for data frames?

# %%
sampledf.info()
sam

# %% [markdown]
# What other attributes and methods can you use on a dataframe? Try them on `sampledf`<br>
# The methods and attributes for dataframes are found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html)

# %% [markdown]
# **Task**: Try working with the methods and attributes of data frames on the `airports.csv` dataset

# %%
airports = pd.read_csv('airports.csv')

# %%
print(airports.axes)
airports = airports.set_index('AIRPORT')
print(airports.axes)
# Out:
# [RangeIndex(start=0, stop=322, step=1), Index(['IATA_CODE', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE'],
#       dtype='object')]
# [Index(['Lehigh Valley International Airport', 'Abilene Regional Airport',
#        'Albuquerque International Sunport', 'Aberdeen Regional Airport',
#        'Southwest Georgia Regional Airport', 'Nantucket Memorial Airport',
#        'Waco Regional Airport', 'Arcata Airport',
#        'Atlantic City International Airport', 'Adak Airport',
#        ...
#        'McGhee Tyson Airport',
#        'Northeast Florida Regional Airport (St. Augustine Airport)',
#        'Valdez Airport', 'Valdosta Regional Airport',
#        'Destin-Fort Walton Beach Airport/Eglin AFB', 'Wrangell Airport',
#        'Westerly State Airport', 'Northwest Arkansas Regional Airport',
#        'Yakutat Airport', 'Yuma International Airport'],
#       dtype='object', name='AIRPORT', length=322), Index(['IATA_CODE', 'CITY', 'STATE', 'COUNTRY', 'LATITUDE', 'LONGITUDE'], dtype='object')]

# %%
airports.values
# Out:
# array([['ABE', 'Allentown', 'PA', 'USA', 40.652359999999994, -75.4404],
#        ['ABI', 'Abilene', 'TX', 'USA', 32.41132, -99.6819],
#        ['ABQ', 'Albuquerque', 'NM', 'USA', 35.04022, -106.60918999999998],
#        ...,
#        ['XNA', 'Fayetteville/Springdale/Rogers', 'AR', 'USA', 36.28187,
#         -94.30681],
#        ['YAK', 'Yakutat', 'AK', 'USA', 59.50336, -139.66023],
#        ['YUM', 'Yuma', 'AZ', 'USA', 32.65658, -114.60597]], dtype=object)

# %%
airports.style
# Out:
# <style  type="text/css" >
# </style><table id="T_54db7708_f73b_11e9_b12d_7831c1bee92c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >IATA_CODE</th>        <th class="col_heading level0 col1" >CITY</th>        <th class="col_heading level0 col2" >STATE</th>        <th class="col_heading level0 col3" >COUNTRY</th>        <th class="col_heading level0 col4" >LATITUDE</th>        <th class="col_heading level0 col5" >LONGITUDE</th>    </tr>    <tr>        <th class="index_name level0" >AIRPORT</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_54db7708_f73b_11e9_b12d_7831c1bee92clevel0_row0" class="row_heading level0 row0" >Lehigh Valley International Airport</th>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow0_col0" class="data row0 col0" >ABE</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow0_col1" class="data row0 col1" >Allentown</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow0_col2" class="data row0 col2" >PA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow0_col3" class="data row0 col3" >USA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow0_col4" class="data row0 col4" >40.6524</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow0_col5" class="data row0 col5" >-75.4404</td>
#             </tr>
#             <tr>
#                         <th id="T_54db7708_f73b_11e9_b12d_7831c1bee92clevel0_row1" class="row_heading level0 row1" >Abilene Regional Airport</th>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow1_col0" class="data row1 col0" >ABI</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow1_col1" class="data row1 col1" >Abilene</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow1_col2" class="data row1 col2" >TX</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow1_col3" class="data row1 col3" >USA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow1_col4" class="data row1 col4" >32.4113</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow1_col5" class="data row1 col5" >-99.6819</td>
#             </tr>
#             <tr>
#                         <th id="T_54db7708_f73b_11e9_b12d_7831c1bee92clevel0_row2" class="row_heading level0 row2" >Albuquerque International Sunport</th>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow2_col0" class="data row2 col0" >ABQ</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow2_col1" class="data row2 col1" >Albuquerque</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow2_col2" class="data row2 col2" >NM</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow2_col3" class="data row2 col3" >USA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow2_col4" class="data row2 col4" >35.0402</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow2_col5" class="data row2 col5" >-106.609</td>
#             </tr>
#             <tr>
#                         <th id="T_54db7708_f73b_11e9_b12d_7831c1bee92clevel0_row3" class="row_heading level0 row3" >Aberdeen Regional Airport</th>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow3_col0" class="data row3 col0" >ABR</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow3_col1" class="data row3 col1" >Aberdeen</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow3_col2" class="data row3 col2" >SD</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow3_col3" class="data row3 col3" >USA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow3_col4" class="data row3 col4" >45.4491</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow3_col5" class="data row3 col5" >-98.4218</td>
#             </tr>
#             <tr>
#                         <th id="T_54db7708_f73b_11e9_b12d_7831c1bee92clevel0_row4" class="row_heading level0 row4" >Southwest Georgia Regional Airport</th>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow4_col0" class="data row4 col0" >ABY</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow4_col1" class="data row4 col1" >Albany</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow4_col2" class="data row4 col2" >GA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow4_col3" class="data row4 col3" >USA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow4_col4" class="data row4 col4" >31.5355</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow4_col5" class="data row4 col5" >-84.1945</td>
#             </tr>
#             <tr>
#                         <th id="T_54db7708_f73b_11e9_b12d_7831c1bee92clevel0_row5" class="row_heading level0 row5" >Nantucket Memorial Airport</th>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow5_col0" class="data row5 col0" >ACK</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow5_col1" class="data row5 col1" >Nantucket</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow5_col2" class="data row5 col2" >MA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow5_col3" class="data row5 col3" >USA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow5_col4" class="data row5 col4" >41.2531</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow5_col5" class="data row5 col5" >-70.0602</td>
#             </tr>
#             <tr>
#                         <th id="T_54db7708_f73b_11e9_b12d_7831c1bee92clevel0_row6" class="row_heading level0 row6" >Waco Regional Airport</th>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow6_col0" class="data row6 col0" >ACT</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow6_col1" class="data row6 col1" >Waco</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow6_col2" class="data row6 col2" >TX</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow6_col3" class="data row6 col3" >USA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow6_col4" class="data row6 col4" >31.6113</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow6_col5" class="data row6 col5" >-97.2305</td>
#             </tr>
#             <tr>
#                         <th id="T_54db7708_f73b_11e9_b12d_7831c1bee92clevel0_row7" class="row_heading level0 row7" >Arcata Airport</th>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow7_col0" class="data row7 col0" >ACV</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow7_col1" class="data row7 col1" >Arcata/Eureka</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow7_col2" class="data row7 col2" >CA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow7_col3" class="data row7 col3" >USA</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow7_col4" class="data row7 col4" >40.9781</td>
#                         <td id="T_54db7708_f73b_11e9_b12d_7831c1bee92crow7_col5" class="data row7 col5" >-124.109</td>
#             </tr>
#             <tr>
#                         <th id="T_54db7708_f73b_11e9_b12d_7831c1bee92clevel0_row8" class="row_heading level0 row8" >Atlantic City International Airport</th>

# %%
airports = airports.reset_index()
airports.at[2, 'CITY']
# Out:
# 'Albuquerque'

# %%
airports.columns
# Out:
# Index(['IATA_CODE', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE'],
#       dtype='object')

# %%
airports.shape
# Out:
# (322, 7)

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 7 columns):
# IATA_CODE    322 non-null object
# AIRPORT      322 non-null object
# CITY         322 non-null object
# STATE        322 non-null object
# COUNTRY      322 non-null object
# LATITUDE     319 non-null float64
# LONGITUDE    319 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 17.7+ KB

# %%
airports.transpose().head()
# Out:
#                                            0                         1    \
# AIRPORT    Lehigh Valley International Airport  Abilene Regional Airport
# IATA_CODE                                  ABE                       ABI
# CITY                                 Allentown                   Abilene
# STATE                                       PA                        TX
# COUNTRY                                    USA                       USA
#
#                                          2                          3    \
# AIRPORT    Albuquerque International Sunport  Aberdeen Regional Airport
# IATA_CODE                                ABQ                        ABR
# CITY                             Albuquerque                   Aberdeen
# STATE                                     NM                         SD
# COUNTRY                                  USA                        USA
#
#                                           4                           5    \
# AIRPORT    Southwest Georgia Regional Airport  Nantucket Memorial Airport
# IATA_CODE                                 ABY                         ACK
# CITY                                   Albany                   Nantucket
# STATE                                      GA                          MA
# COUNTRY                                   USA                         USA
#
#                              6               7    \
# AIRPORT    Waco Regional Airport  Arcata Airport
# IATA_CODE                    ACT             ACV
# CITY                        Waco   Arcata/Eureka
# STATE                         TX              CA
# COUNTRY                      USA             USA
#
#                                            8             9    ...  \
# AIRPORT    Atlantic City International Airport  Adak Airport  ...
# IATA_CODE                                  ACY           ADK  ...
# CITY                             Atlantic City          Adak  ...
# STATE                                       NJ            AK  ...
# COUNTRY                                    USA           USA  ...
#
#                             312  \
# AIRPORT    McGhee Tyson Airport
# IATA_CODE                   TYS
# CITY                  Knoxville
# STATE                        TN
# COUNTRY                     USA
#
#                                                          313             314  \
# AIRPORT    Northeast Florida Regional Airport (St. August...  Valdez Airport
# IATA_CODE                                                UST             VEL
# CITY                                           St. Augustine          Vernal
# STATE                                                     FL              UT
# COUNTRY                                                  USA             USA
#
#                                  315  \
# AIRPORT    Valdosta Regional Airport
# IATA_CODE                        VLD
# CITY                        Valdosta
# STATE                             GA
# COUNTRY                          USA
#
#                                                   316               317  \
# AIRPORT    Destin-Fort Walton Beach Airport/Eglin AFB  Wrangell Airport
# IATA_CODE                                         VPS               WRG
# CITY                                       Valparaiso          Wrangell
# STATE                                              FL                AK
# COUNTRY                                           USA               USA
#
#                               318                                  319  \
# AIRPORT    Westerly State Airport  Northwest Arkansas Regional Airport
# IATA_CODE                     WYS                                  XNA
# CITY             West Yellowstone       Fayetteville/Springdale/Rogers
# STATE                          MT                                   AR
# COUNTRY                       USA                                  USA
#
#                        320                         321
# AIRPORT    Yakutat Airport  Yuma International Airport
# IATA_CODE              YAK                         YUM
# CITY               Yakutat                        Yuma
# STATE                   AK                          AZ
# COUNTRY                USA                         USA
#
# [5 rows x 322 columns]

# %% [markdown]
# ### Quick knowledge check:

# %% [markdown]
# - Where can you find the list of available attributes and methods for a pre-created class?

# %% [markdown]
# - what's the key difference between an attribute and a method?

# %% [markdown]
# - What is the appropriate sequence of these words?  A variable becomes an _______ when you _______ a _______ .
#  - A: Initialize
#  - B: Class
#  - C: Object

# %% [markdown]
# ### So creating a _class_ is essentially creating a _blueprint_ for how you want to store and manipulate data.
#
# ![blueprint](img/blueprint.jpeg)

# %% [markdown]
# ## Quick Scavenger Hunt!!
# - In small groups - use the code links bellow to find where each object is created as a *class*.
# - Then find the location in the code where a method or attribute you have used is _defined_.
# - Share the links to the exact lines of code on the class slack channel!

# %% [markdown]
# Matplotlib:
# - [matplotlib axes](https://matplotlib.org/3.1.1/_modules/matplotlib/axes/_axes.html)
# - [matplotlib figure](https://matplotlib.org/3.1.1/_modules/matplotlib/figure.html)
#
# Seaborn:
# - [Facet grid](https://github.com/mwaskom/seaborn/blob/master/seaborn/axisgrid.py)
#
# Pandas:
# - [series](https://github.com/pandas-dev/pandas/blob/master/pandas/core/series.py)

# %% [markdown]
# ### Let's start by making a car `class` and giving it some `attributes`

# %%
class Car():
    pass

# %%
ferrari = Car()
lambo = Car()

# %% [markdown]
# #### Check the class of lambo

# %%
type(lambo)

# %% [markdown]
# #### Can assign attributes to a class object after it's been defined and intitialized

# %%
ferrari.max_speed = 200
ferrari.max_speed

# %% [markdown]
# #### But what if we try to return the `max_speed` of lambo?

# %%
lambo.max_speed

# %% [markdown]
# #### Let's update our car class so it has more attributes

# %%
class Car():
    wheels = 4

# %%
ford = Car()
ford.wheels

# %% [markdown]
# #### What if we wanted to set some parameters when we initialize the object?

# %%
class Car():
    wheels = 4
    def __init__(self, max_speed, c_type):
        self.max_speed = max_speed
        self.c_type = c_type
        self.moving = False
    
    def stop(self):
        print('Stopped')
        self.moving = False
        
    def go(self):
        print('Moving')
        self.moving = True

# %%
lambo = Car(200, 'sport')

# %%
lambo.moving
# Out:
# False

# %%
lambo.go()
# Out:
# Moving

# %%
lambo.stop()
# Out:
# Stopped

# %% [markdown]
# #### Confirm our assignment worked

# %%
print(lambo.wheels)
print(lambo.max_speed)
print(lambo.c_type)

# %% [markdown]
# #### What if you try to initialize it without one of the terms?

# %%
test = Car(55)

# %% [markdown]
# ## Now let's create a method for our car class

# %%
class Car():
    wheels = 4

    def __init__(self, max_speed, c_type):
        self.max_speed = max_speed
        self.c_type = c_type

    def go(self):
        print('going')
        self.moving = True

# %% [markdown]
# #### **Task** create another method for car `stop`
#
# - stop should print 'stopped'
# - stop should set the attribute `moving` to `False`

# %% [markdown]
# **Task**: Make a pizza class<br>
#
# - Pizza should take one topping and the size of the pizza when instantiated
# - Pizza should have an attribute `toppings` that stores toppings in a list
# - Pizza should have methods `.add_topping`, `print_toppings`, and `remove_topping`

# %% [markdown]
# **Extra Credit**
#
# - Pizza should have an attribute "order_status" that starts as equaling `none`. order_status should change depending on the methods:
#  - `done_adjusting_order`
#  - `preparing`
#  - `delivering`
#  - `delivered`
# - order_status, when called, should return in the form of a sentence.

# %% [markdown]
# ### Integration
# Make a plan for a stock class
#
# - What would you want it to take when instantiated?
# - what methods would you want it to have?
# - for predicting, would you want it to default to one modeling technique? or would you be able to specify?
# - What input data would it take?
# - What attributes would you want to be able to reference?

# %% [markdown]
# ## Reflection
#
# ![traffic](img/stoplight.jpeg)
#
# [Exit Ticket](https://docs.google.com/forms/d/1r-AHQ8HdCuWpepbu4CKlKULeofEiTGfR7rKgKO-oyRI/edit)
